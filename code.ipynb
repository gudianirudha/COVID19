# %% [markdown]
# # Welcome to Covid19 Data Analysis Notebook
# ------------------------------------------

# %% [markdown]
# ### Let's Import the modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported.')
# Out:
# Modules are imported.

# %% [markdown]
# ## Task 2

# %% [markdown]
# ### Task 2.1: importing covid19 dataset
# importing "Covid19_Confirmed_dataset.csv" from "./Dataset" folder.

# %%
corona_dataset_csv= pd.read_csv("Datasets/covid19_Confirmed_dataset.csv")
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %% [markdown]
# #### Let's check the shape of the dataframe

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %% [markdown]
# ### Task 2.2: Delete the useless columns

# %%
df = corona_dataset_csv.drop(["Lat","Long"],axis=1)

# %%
df.head(12)
# Out:
#                   Province/State       Country/Region  1/22/20  1/23/20  \
# 0                            NaN          Afghanistan        0        0
# 1                            NaN              Albania        0        0
# 2                            NaN              Algeria        0        0
# 3                            NaN              Andorra        0        0
# 4                            NaN               Angola        0        0
# 5                            NaN  Antigua and Barbuda        0        0
# 6                            NaN            Argentina        0        0
# 7                            NaN              Armenia        0        0
# 8   Australian Capital Territory            Australia        0        0
# 9                New South Wales            Australia        0        0
# 10            Northern Territory            Australia        0        0
# 11                    Queensland            Australia        0        0
#
# ...

# %% [markdown]
# ### Task 2.3: Aggregating the rows by the country

# %%
corona_dataset_agreegated = df.groupby("Country/Region").sum()

# %%
corona_dataset_agreegated.tail()
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
#                     1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  \
# Country/Region                                          ...
# West Bank and Gaza        0        0        0        0  ...      466      474
# Western Sahara            0        0        0        0  ...        6        6
# Yemen                     0        0        0        0  ...        1        1
# Zambia                    0        0        0        0  ...       70       74
# ...

# %%
corona_dataset_agreegated.loc["India"].plot()
corona_dataset_agreegated.loc["Pakistan"].plot()
plt.legend()

# %% [markdown]
# ### Task 2.4: Visualizing data related to a country for example China
# visualization always helps for better understanding of our data.

# %%
corona_dataset_agreegated.loc["India"][3:].plot()

# %% [markdown]
# ### Task3: Calculating a good measure
# we need to find a good measure reperestend as a number, describing the spread of the virus in a country.

# %%
corona_dataset_agreegated.loc['India'][12:].plot()

# %% [markdown]
# ### task 3.1: caculating the first derivative of the curve

# %%
corona_dataset_agreegated.loc["India"].diff().plot()

# %% [markdown]
# ### task 3.2: find maxmimum infection rate for China

# %%
corona_dataset_agreegated.loc["India"].diff().max()
# Out:
# 1893.0

# %%
corona_dataset_agreegated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# ### Task 3.3: find maximum infection rate for all of the countries.

# %%
countries = list(corona_dataset_agreegated.index)
max_infected_rate=[]
for c in countries:
    max_infected_rate.append(corona_dataset_agreegated.loc[c].diff().max())

# %%
corona_dataset_agreegated["Max_Infected"] = max_infected_rate

# %% [markdown]
# ### Task 3.4: create a new dataframe with only needed column

# %%
corona_dataset_agreegated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
corona_data = pd.DataFrame(corona_dataset_agreegated["Max_Infected"])
corona_data
# Out:
#                         Max_Infected
# Country/Region
# Afghanistan                    232.0
# Albania                         34.0
# Algeria                        199.0
# Andorra                         43.0
# Angola                           5.0
# Antigua and Barbuda              6.0
# Argentina                      291.0
# Armenia                        134.0
# Australia                      497.0
# Austria                       1321.0
# Azerbaijan                     105.0
# Bahamas                          7.0
# Bahrain                        301.0
# Bangladesh                     641.0
# Barbados                        12.0
# Belarus                       1485.0
# Belgium                       2454.0
# Belize                           4.0
# Benin                           19.0
# Bhutan                           1.0
# Bolivia                        104.0
# Bosnia and Herzegovina          92.0
# Botswana                         7.0
# Brazil                        7502.0
# ...

# %% [markdown]
# ### Task4:
# - Importing the WorldHappinessReport.csv dataset
# - selecting needed columns for our analysis
# - join the datasets
# - calculate the correlations as the result of our analysis

# %% [markdown]
# ### Task 4.1 : importing the dataset

# %%
happiness_report_csv = pd.read_csv("Datasets/worldwide_happiness_report.csv")

# %%
happiness_report_csv.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %% [markdown]
# ### Task 4.2: let's drop the useless columns

# %%
report = happiness_report_csv.drop(["Overall rank","Score","Generosity","Perceptions of corruption"],axis=1)

# %%
report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %% [markdown]
# ### Task 4.3: changing the indices of the dataframe

# %%
report.set_index("Country or region",inplace=True)

# %% [markdown]
# ### Task4.4: now let's join two dataset we have prepared

# %%
report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %% [markdown]
# #### Corona Dataset :

# %%
corona_data.head()
# Out:
#                 Max_Infected
# Country/Region
# Afghanistan            232.0
# Albania                 34.0
# Algeria                199.0
# Andorra                 43.0
# Angola                   5.0

# %% [markdown]
# #### wolrd happiness report Dataset :

# %%
report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report_csv.shape



corona_data.shape
# Out:
# (187, 1)

# %% [markdown]
# ### Task 4.5: correlation matrix

# %%
data = corona_data.join(report,how="inner")
data.head()
# Out:
#              Max_Infected  GDP per capita  Social support  \
# Afghanistan         232.0           0.350           0.517
# Albania              34.0           0.947           0.848
# Algeria             199.0           1.002           1.160
# Argentina           291.0           1.092           1.432
# Armenia             134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %% [markdown]
# ### Task 5: Visualization of the results
# our Analysis is not finished unless we visualize the results in terms figures and graphs so that everyone can understand what you get out of our analysis

# %%
data.corr()
# Out:
#                               Max_Infected  GDP per capita  Social support  \
# Max_Infected                      1.000000        0.250118        0.191958
# GDP per capita                    0.250118        1.000000        0.759468
# Social support                    0.191958        0.759468        1.000000
# Healthy life expectancy           0.289263        0.863062        0.765286
# Freedom to make life choices      0.078196        0.394603        0.456246
#
#                               Healthy life expectancy  \
# Max_Infected                                 0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
#
#                               Freedom to make life choices
# Max_Infected                                      0.078196
# GDP per capita                                    0.394603
# ...

# %% [markdown]
# ### Task 5.1: Plotting GDP vs maximum Infection rate

# %%
x = data["GDP per capita"]
y = data["Max_Infected"]

sns.regplot(x,np.log(y))

# %%
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.2: Plotting Social support vs maximum Infection rate

# %%
x = data["Social support"]
y = data["Max_Infected"]

sns.regplot(x,np.log(y))

# %% [markdown]
# ### Task 5.3: Plotting Healthy life expectancy vs maximum Infection rate

# %%
x = data["Healthy life expectancy"]
y = data["Max_Infected"]

sns.scatterplot(x,np.log(y))

# %% [markdown]
# ### Task 5.4: Plotting Freedom to make life choices vs maximum Infection rate

# %%
x = data["Freedom to make life choices"]
y = data["Max_Infected"]

sns.scatterplot(x,np.log(y))
